# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Criando um dataset em Python
#
# Vamos criar um dataset usando uma lista de tuplas em Python

# %%
dataset = [
    (1, 2, "A"),
    (2, 1, "A"),
    (3, 3, "A"),
    (4, 4, "B"),
    (5, 6, "B"),
    (6, 2, "B")
]

dataset
# Out:
# [(1, 2, 'A'), (2, 1, 'A'), (3, 3, 'A'), (4, 4, 'B'), (5, 6, 'B'), (6, 2, 'B')]

# %% [markdown]
# # Instância de teste
# x1 = 4
# x2 = 5
# Classe = ?

# %%
def kNN(dataset, teste, k):
    # Criar uma lista com as distância entre as instâncias
    distancias = []

    # Varrer as linhas do meu dataset, e calcular as distâncias em relação à instância de teste.
    for linha in dataset:
        # Calcular a distância euclidiana para a instância de teste.
        di = math.sqrt((linha[0]-teste[0])**2 + (linha[1] - teste[1]) ** 2)
        # Adicionando uma nova coluna no dataset que representa a distância da instância em relação ao teste
        d_calculado = (linha[0], linha[1], linha[2], di)
        # Adicionar na lista de distâncias
        distancias.append(d_calculado)
 
    distancias.sort(key = lambda x:x[3])
    nA = 0
    nB = 0
    for linha in distancias[:k]:
        if linha[2] == "A":
            nA += 1
        else:
            nB += 1

    if nA > nB:
        return "A classe será A"
    else:
        return "A classe será B"

# %%
testes = [(1, 0), (2, 5), (7, 3), (4, 2), (6, 4), (9, 4)]

for teste in testes:
    print(teste, kNN(dataset, teste, 3))
# Out:
# (1, 0) A classe será A
# (2, 5) A classe será A
# (7, 3) A classe será B
# (4, 2) A classe será B
# (6, 4) A classe será B
# (9, 4) A classe será B

# %%
import matplotlib.pyplot as plt

x1a = []
x1b = []
x2a = []
x2b = []
x1t = []
x2t = []

for linha in dataset:
    if linha[2] == "A":
        x1a.append(linha[0])
        x2a.append(linha[1])
    else:
        x1b.append(linha[0])
        x2b.append(linha[1])

for linha in testes:
    x1t.append(linha[0])
    x2t.append(linha[1])

# %%
for i in range(len(x1t)):
    plt.scatter(x1a, x2a, c='red')
    plt.scatter(x1b, x2b, c='blue')
    plt.scatter(x1t[i], x2t[i], c='green', marker="^")
    plt.show()
